# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('heart_disease_prediction.csv')

# %%
columns = list(df.columns)
columns
# Out:
# ['HeartDisease',
#  'BMI',
#  'Smoking',
#  'AlcoholDrinking',
#  'Stroke',
#  'PhysicalHealth',
#  'MentalHealth',
#  'DiffWalking',
#  'Sex',
#  'AgeCategory',
#  'Race',
#  'Diabetic',
#  'PhysicalActivity',
#  'GenHealth',
#  'SleepTime',
#  'Asthma',
#  'KidneyDisease',
#  'SkinCancer']

# %%
df.loc[10:20,['Smoking','Asthma']]
# Out:
#    Smoking Asthma
# 10     Yes    Yes
# 11     Yes     No
# 12     Yes     No
# 13      No     No
# 14     Yes     No
# 15      No     No
# 16      No     No
# 17     Yes     No
# 18     Yes     No
# 19      No     No
# 20      No     No

# %%
df['Smoking'] == 'Yes'
# Out:
# 0          True
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 319790     True
# 319791     True
# 319792    False
# 319793    False
# 319794    False
# Name: Smoking, Length: 319795, dtype: bool

# %%
df.loc[(df['Smoking'] == 'Yes') & (df['BMI'] > 20),:]
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 2                No  26.58     Yes              No     No            20.0
# 5               Yes  28.87     Yes              No     No             6.0
# 7                No  31.64     Yes              No     No             5.0
# 10              Yes  34.30     Yes              No     No            30.0
# 11               No  28.71     Yes              No     No             0.0
# ...             ...    ...     ...             ...    ...             ...
# 319782           No  31.89     Yes              No     No            30.0
# 319784           No  26.58     Yes              No     No             0.0
# 319786          Yes  33.20     Yes              No     No             0.0
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
df.loc[df['AgeCategory'].isin(['65-69','60-64']),:]
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 2                No  26.58     Yes              No     No            20.0
# 9                No  40.69      No              No     No             0.0
# 10              Yes  34.30     Yes              No     No            30.0
# 14               No  29.29     Yes              No     No             0.0
# 25               No  29.18     Yes              No     No            30.0
# ...             ...    ...     ...             ...    ...             ...
# 319777           No  42.57      No              No     No             0.0
# 319785           No  31.93      No             Yes     No             0.0
# 319786          Yes  33.20     Yes              No     No             0.0
# 319788           No  23.38      No              No     No             0.0
# 319790          Yes  27.41     Yes              No     No             7.0
#
#         MentalHealth DiffWalking     Sex AgeCategory      Race Diabetic  \
# ...

# %%
df2 = df
df2.iat[3,3] = 'Yes'
df2.loc[df['BMI'] > 20,'PhysicalHealth'] = 7.0
df2
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             7.0
# 2                No  26.58     Yes              No     No             7.0
# 3                No  24.21      No             Yes     No             7.0
# 4                No  23.71      No              No     No             7.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             7.0
# 319792           No  24.24      No              No     No             7.0
# 319793           No  32.81      No              No     No             7.0
# 319794           No  46.56      No              No     No             7.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
for idx,row in enumerate(df):
    print(row)
# Out:
# HeartDisease
# BMI
# Smoking
# AlcoholDrinking
# Stroke
# PhysicalHealth
# MentalHealth
# DiffWalking
# Sex
# AgeCategory
# Race
# Diabetic
# PhysicalActivity
# GenHealth
# SleepTime
# Asthma
# KidneyDisease
# SkinCancer

# %%
for row in df.itertuples():
    print(row.PhysicalHealth)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/nx/v0w0fwv13hq25_4ngqjjk9kr0000gn/T/ipykernel_64411/1535639386.py in <module>
#       1 for row in df.itertuples():
# ----> 2     print(row['PhysicalHealth'])
#
# TypeError: tuple indices must be integers or slices, not str

# %%
df2 = df.iloc[:,0:5]
df3 = df.iloc[:,5:10]
df4 = df.iloc[:,10:18]

con_df = pd.concat((df2,df3,df4), axis = 1)
con_df2 = pd.concat((df2,df3,df4), axis = 0)

# %%
s1 = df.iloc[0:1,:]
con_df = pd.concat((s1, con_df), axis = 0)

# %%
df['key'] = range(0,319795)

p1 = df.loc[:,['HeartDisease',
 'BMI',
 'Smoking',
 'AlcoholDrinking',
 'Stroke',
 'PhysicalHealth',
 'MentalHealth',
 'DiffWalking',
 'Sex',
 'key']]

p2 = df.loc[:,['AgeCategory',
 'Race',
 'Diabetic',
 'PhysicalActivity',
 'GenHealth',
 'SleepTime',
 'Asthma',
 'KidneyDisease',
 'SkinCancer',
 'key']]

# %%
p3 = pd.merge(p1,p2,on = 'key')

# %%
group_df = df.groupby('Race')

# %%
for group in group_df:
    print(group[0])
# Out:
# American Indian/Alaskan Native
# Asian
# Black
# Hispanic
# Other
# White

# %%
np.mean(group_df.get_group('Asian')['SleepTime'])
# Out:
# 6.918691125433813

# %%
asian_df = group_df.get_group('Asian')
